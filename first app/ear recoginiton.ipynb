# %%
import sys
import cv2
import imutils
import numpy as np

# %%
#imaj=cv2.imread("anonymous.jpg")
  
# Let's load a simple image with 3 black squares 
image = cv2.imread('7a.jpg') 
cv2.waitKey(0) 
  
# Grayscale 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
#cv2.imshow('Contours', gray) 
  
# Find Canny edges 
edged = cv2.Canny(gray, 50, 450) 
cv2.waitKey(0) 
  
# Finding Contours 
# Use a copy of the image e.g. edged.copy() 
# since findContours alters the image 
contours, hierarchy = cv2.findContours(edged,  
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
  
cv2.imshow('Canny Edges After Contouring', edged) 
cv2.waitKey(0) 
  
print("Number of Contours found = " + str(len(contours))) 
#print(contours)
  
# Draw all contours 
# -1 signifies drawing all contours 
cv2.drawContours(image, contours[0], -1, (0, 255, 0), 3) 
cv2.drawContours(image, contours[1], -1, (0, 255, 0), 3) 
cv2.drawContours(image, contours[2], -1, (0, 255, 0), 3) 
#cv2.drawContours(image, contours[3], -1, (0, 255, 0), 3) 
#cv2.drawContours(image, contours[4], -1, (0, 255, 0), 3) 
cv2.drawContours(image, contours[5], -1, (0, 255, 0), 3) 

#print(contours[1])
p1= px
p2 =py
p_middle=(x_m_point,y_m_point)
p_line1=(0,y_m_point)
p_line2=(x_m_point+100,y_m_point)

theta = np.arctan2(p1[1]-p2[1], p1[0]-p2[0])
endpt_x = int(p1[0] - 1000*np.cos(theta))
endpt_y = int(p1[1] - 1000*np.sin(theta))
cv2.line(image, (p1[0], p1[1]), (endpt_x, endpt_y), 255, 2)
cv2.line(image,(p_line1[0], p_line1[1]), (p_line2[0], p_line2[1]), 255, 2)
cv2.line(image,(p_line1[0], (p_line1[1]+60)), (p_line2[0], (p_line2[1]+60)), 255, 2)
cv2.line(image,(p_line1[0], (p_line1[1]+120)), (p_line2[0], (p_line2[1]+120)), 255, 2)
#cv2.line(image,(p_line1[0], (p_line1[1]+180)), (p_line2[0], (p_line2[1]+180)), 255, 2)
cv2.line(image,(p_line1[0], (p_line1[1]-60)), (p_line2[0], (p_line2[1]-60)), 255, 2)
cv2.line(image,(p_line1[0], (p_line1[1]-120)), (p_line2[0], (p_line2[1]-120)), 255, 2)
cv2.imshow('Contours', image) 

cv2.waitKey(0) 
cv2.destroyAllWindows()
# Out:
# Number of Contours found = 6

# %%
cv2.imwrite('image.jpg', image)
# Out:
# True

# %%
imager = cv2.imread('image.jpg')
p_middle=(x_m_point,y_m_point)
cv2.line(imager, (p_middle[0],p_middle[1]), (24, 81), 255, 2)
cv2.line(imager, (p_middle[0],p_middle[1]), (230, 81), 255, 2)
cv2.line(imager, (p_middle[0],p_middle[1]), (10, 141), 255, 2)
cv2.line(imager, (p_middle[0],p_middle[1]), (10, 201), 255, 2)
cv2.line(imager, (p_middle[0],p_middle[1]), (25, 261), 255, 2)
cv2.line(imager, (p_middle[0],p_middle[1]), (60, 321), 255, 2)
cv2.imshow('imager', imager) 

cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
cv2.imwrite('imager.jpg', imager)
# Out:
# True

# %%
import math
 
def getAngle(a, b, c):
    ang = math.degrees(math.atan2(c[1]-b[1], c[0]-b[0]) - math.atan2(a[1]-b[1], a[0]-b[0]))
    return ang + 360 if ang < 0 else ang
 
print(getAngle((5, 0), (0, 0), (0, 5)))
# Out:
# 90.0

# %%
print(getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(230, 81)))
print(360-getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(10, 141)))
print(360-getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(10, 201)))
print(360-getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(25, 261)))
print(360-getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(60, 321)))
print(360-getAngle((endpt_x, endpt_y),(x_m_point, y_m_point),(24, 81)))
# Out:
# 47.016970815221896
# 48.725880801308335
# 69.16483671622132
# 91.50548467621547
# 116.39601132425258
# 29.93916261888461

# %%
centers=[] 
for c in contours:
        # If contours are too small or large, ignore them:
        if cv2.contourArea(c)<800:
            continue
        elif cv2.contourArea(c)>3000:
            continue
        cv2.drawContours(image, [c], -1, (0,255,0), 3)

        # Find center point of contours:
        M = cv2.moments(c)
        cX = int(M['m10'] /M['m00'])
        cY = int(M['m01'] /M['m00'])
        centers.append([cX,cY])
        #print(centers)

        # Find the distance D between the two contours:
"""
    if len(centers) >= 2:
        dx= centers[0][0] - centers[1][0]
        dy = centers[0][1] - centers[1][1]
        D = np.sqrt(dx*dx+dy*dy)
        print(D)
"""
#if cv2.waitKey(1) & 0xFF == ord('q'):
centers=np.array(centers)   
print(centers.shape)
cv2.imshow('Contours', image) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
import math  
def calculateDistance(x1,y1,x2,y2):  
     dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)  
     return dist 
#print(contours[5])
print(contours[5].size)
# Out:
# 3462

# %%
mesafeler=[]
x=len(contours[5])
for k in range(0,x):
    for i in range(0,x):
        x1=contours[5][k][0]
        y1=x1[1]
        x1=x1[0]
        x2=contours[5][i][0]
        y2=x2[1]
        x2=x2[0]
        distance=calculateDistance(x1,y1,x2,y2)
        mesafeler.append([distance,x1,y1,x2,y2])

# %%
x,a,b,c,d=max(mesafeler)
px = (a, b)
py = (c, d)
print(px,py)
# Out:
# (245, 394) (98, 9)

# %%
#orta nokta 
x_m_point = int((a + c)/2)
y_m_point = int((b + d)/2)
p_middle=(x_m_point,y_m_point)
p_line1=(0,y_m_point)
p_line2=(x_m_point+100,y_m_point)

# %%
print(y_m_point)
# Out:
# 201

# %%
x=len(contours[5])
for k in range(0,x):
    for i in range(0,x):
        x1=contours[5][k][0]
        y1=x1[1]
        x1=x1[0]
        if y1==y_m_point:
            print(y1,x1)
        elif y1==(y_m_point-60):
            print(y1,x1)
        elif y1==(y_m_point+60):
            print(y1,x1)
        elif y1==(y_m_point-120):
            print(y1,x1)
        elif y1==(y_m_point+120):
            print(y1,x1)
# Out:
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# 81 23
# ...

# %% [markdown]
# # testing

# %%
img_size = (200,200)
img = np.ones(img_size) * 255

# polar equation
theta = np.linspace(0, np.pi, 1000)
r = 1 / (np.sin(theta) - np.cos(theta))

# polar to cartesian
def polar2cart(r, theta):
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

x,y = polar2cart(r, theta)
x1, x2, y1, y2 = x[0], x[1], y[0], y[1]

# line equation y = f(X)
def line_eq(X):
    m = (y2 - y1) / (x2 - x1)
    return m * (X - x1) + y1

line = np.vectorize(line_eq)

x = np.arange(0, img_size[0])
y = line(x).astype(np.uint)

cv2.line(img, (x[0], y[0]), (x[-1], y[-1]), (0,0,0))
cv2.imshow("foo",img)
cv2.waitKey()
# Out:
# -1
